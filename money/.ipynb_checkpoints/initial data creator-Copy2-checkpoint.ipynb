# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import requests
import urllib
import time
import datetime
import threading
import queue

# %%
global days_to_add
days_to_add = 100

# %%
def storeInQueue(f):
    def wrapper(*args):
        my_queue.put(f(*args))
    return wrapper

# %%
pd.options.mode.chained_assignment = 'raise'

# %%
# Use the following site to get list of all publicly traded Stocks
#http://nxcoreapi.com/symbols.php

#nasdaq
#https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download
nqnm = pd.read_csv('nasdaq.csv')
nqnm['Exchange'] = 'Nasdaq'
#nyse
#https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nyse&render=download
nyse = pd.read_csv('nyse.csv')
nyse['Exchange'] = 'NYSE'
#amex
#https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=amex&render=download
amex = pd.read_csv('amex.csv')
amex['Exchange'] = 'AMEX'

# %%
amex
# Out:
#     Symbol                                               Name  LastSale  \
# 0     GOED                                 1847 Goedeker Inc.    7.3500
# 1     XXII                            22nd Century Group, Inc    0.6164
# 2      FAX              Aberdeen Asia-Pacific Income Fund Inc    4.1900
# 3      IAF                 Aberdeen Australia Equity Fund Inc    4.8600
# 4      AEF  Aberdeen Emerging Markets Equity Income Fund, ...    6.7800
# ..     ...                                                ...       ...
# 286    WYY                              WidePoint Corporation    0.5420
# 287    WTT                      Wireless Telecom Group,  Inc.    1.2900
# 288   XTNT                       Xtant Medical Holdings, Inc.    0.8671
# 289   ZDGE                                        Zedge, Inc.    1.4100
# 290    ZOM                     Zomedica Pharmaceuticals Corp.    0.1190
#
#     MarketCap  IPOyear                 Sector  \
# 0     $44.92M   2020.0      Consumer Services
# 1     $85.59M      NaN  Consumer Non-Durables
# 2      $1.04B   1986.0                    NaN
# 3    $110.53M      NaN                    NaN
# 4     $344.1M      NaN                    NaN
# ..        ...      ...                    ...
# 286   $45.75M      NaN             Technology
# 287   $27.93M      NaN          Capital Goods
# 288   $11.47M      NaN            Health Care
# 289    $17.2M   2016.0             Technology
# 290   $67.12M   2017.0            Health Care
#
#                                               industry  \
# 0                                     Home Furnishings
# 1                                Farming/Seeds/Milling
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 286                                       EDP Services
# 287                                Electrical Products
# 288  Biotechnology: Biological Products (No Diagnos...
# 289            Computer Software: Prepackaged Software
# 290                              Major Pharmaceuticals
#
#                           Summary Quote Exchange
# 0    https://old.nasdaq.com/symbol/goed     AMEX
# 1    https://old.nasdaq.com/symbol/xxii     AMEX
# 2     https://old.nasdaq.com/symbol/fax     AMEX
# 3     https://old.nasdaq.com/symbol/iaf     AMEX
# 4     https://old.nasdaq.com/symbol/aef     AMEX
# ..                                  ...      ...
# 286   https://old.nasdaq.com/symbol/wyy     AMEX
# 287   https://old.nasdaq.com/symbol/wtt     AMEX
# 288  https://old.nasdaq.com/symbol/xtnt     AMEX
# 289  https://old.nasdaq.com/symbol/zdge     AMEX
# 290   https://old.nasdaq.com/symbol/zom     AMEX
#
# [291 rows x 9 columns]

# %%
stocks = nyse.copy()
stocks = stocks.append(nqnm)
stocks = stocks.append(amex)
# stocks.tail()
# stocks

# %%
stocks = stocks[['Symbol', 'Name', 'Exchange', 'Sector', 'industry']]
stocks.reset_index(inplace=True)
stocks = stocks.drop(columns=['index'])
stocks
# Out:
#      Symbol                            Name Exchange             Sector  \
# 0       DDD          3D Systems Corporation     NYSE         Technology
# 1       MMM                      3M Company     NYSE        Health Care
# 2      WBAI                 500.com Limited     NYSE  Consumer Services
# 3      WUBA                     58.com Inc.     NYSE         Technology
# 4      EGHT                         8x8 Inc     NYSE         Technology
# ...     ...                             ...      ...                ...
# 7125    WYY           WidePoint Corporation     AMEX         Technology
# 7126    WTT   Wireless Telecom Group,  Inc.     AMEX      Capital Goods
# 7127   XTNT    Xtant Medical Holdings, Inc.     AMEX        Health Care
# 7128   ZDGE                     Zedge, Inc.     AMEX         Technology
# 7129    ZOM  Zomedica Pharmaceuticals Corp.     AMEX        Health Care
#
#                                                industry
# 0               Computer Software: Prepackaged Software
# 1                            Medical/Dental Instruments
# 2                 Services-Misc. Amusement & Recreation
# 3       Computer Software: Programming, Data Processing
# 4                                          EDP Services
# ...                                                 ...
# 7125                                       EDP Services
# 7126                                Electrical Products
# 7127  Biotechnology: Biological Products (No Diagnos...
# 7128            Computer Software: Prepackaged Software
# 7129                              Major Pharmaceuticals
#
# [7130 rows x 5 columns]

# %%
features = ['dividendRate', 'exDividendDate', 'lastSplitDate', 'lastSplitFactor']
    
for feature in features:
    stocks.loc[:, feature] = np.nan
    
stocks[features] = stocks[features].astype('object')

# %%
# # uncomment the following when debugging
# stocks = stocks[0:10]
# stocks

# %%
# get quarterly dates for 75 days in future and 75 days in past
def makeQuarterlyDicts():
    
    #get the business days
    quarterly_df = pd.DataFrame()
    start = pd.to_datetime('today') - pd.to_timedelta(days_to_add, unit='d')
    end = pd.to_datetime('today') + pd.to_timedelta(days_to_add, unit='d')
    quarterly_df['Business Dates'] = pd.bdate_range(start=start, end=end)
    
    previous_dict = {}
    future_dict = {}
    holidays = []

    for row in quarterly_df.itertuples():
#         print (row[1])

        date = row[1]
        day = str(row[1])[0:10]
        url = 'https://finance.yahoo.com/calendar/earnings/?day='+day


        # add to previous earnings dates
        try:
            earnings = pd.read_html(url)[0]
            if row[1] < pd.to_datetime('today'):
                for earnings_row in earnings.itertuples():
                    previous_dict[earnings_row[1]] = (date, earnings_row[4], earnings_row[5], earnings_row[6])

            # add to future earnings dates
            else:
                for earnings_row in earnings.itertuples():
                    future_dict[earnings_row[1]] = (date)
        except (ValueError):
            holidays.append(date)
            e = sys.exc_info()[0]
            print(e)
    
    return previous_dict, future_dict

# %%
def QuarterlyInfo(stocks):
    initial_time = round(time.time())
    
    previous_dict, future_dict = makeQuarterlyDicts()
    
    previous = pd.DataFrame.from_dict(previous_dict, orient='index',
                                  columns=['Previous_Earnings_Date', 'Expected', 'Actual', 'Surprise'])
    future = pd.DataFrame.from_dict(future_dict, orient = 'index', columns=['Future Earnings Date'])
    
    previous = previous.reset_index()
    future = future.reset_index()
    
    previous.rename(columns={'index': 'Symbol'}, inplace=True)
    future.rename(columns={'index': 'Symbol'}, inplace=True)
    
    stocks = pd.merge(stocks, previous, how='inner')
    stocks = pd.merge(stocks, future, how='left')
    
    print ('Finished quarterly thread in ', (round(time.time())-initial_time)/ 60.0, " minutes!")
    
    return stocks

# %%
def getInfo(symbol, info=True, calendar=True, quarterly_financials=True):
    connection_tries=0
    j=0
    
    info = {}
    ticker = yf.Ticker(symbol)           
    info_bool = False
    while 1:
        
        try:
            if info_bool == False:
                info = ticker.info
                info_bool = True
                           
            return info
            
        except (urllib.error.HTTPError, requests.exceptions.ConnectionError) as e:
            
            if connection_tries < 1:
                print (e, "HTTP Error. Will try again in 10 seconds")
                time.sleep(10)
                connection_tries +=1
            elif connection_tries < 2:
                print (e, "HTTP Error. Will try again in 30 seconds")
                time.sleep(30)
                connection_tries +=1
            elif connection_tries < 4:
                print (e, "HTTP Error. Will try again in 5 minutes")
                time.sleep(300)
                connection_tries +=1
            elif connection_tries < 5:
                print (e, "HTTP Error.  Will try again in 1 hour")
                time.sleep(3600)
                connection_tries +=1
            else:
                connection_tries = 0
                print (e, "HTTP Error.  Giving up.")
                return {}, pd.DataFrame(), pd.DataFrame()
        except:
            e = sys.exc_info()[0]
#             print('here: ', e)
            if j>2:
                return 'error'
            j+=1

# %%
@storeInQueue
def info_thread(stocks, features):
    i = 0
    initial_time = round(time.time())

    bad_symbols = []
    symbols_with_no_return = []

    for row in stocks.itertuples():
        print ("Info Thread: ", i)    
        if i % 100 == 0:
            print ("It has been: ", (round(time.time())-initial_time)/ 60.0, " minutes in info thread")
        if '/' in row[1]:
            print ('Bad symbol in ', row[1])
            bad_symbols.append(i)
        elif '.' in row[1]:
            print ('Bad symbol in ', row[1])
            bad_symbols.append(i)
        elif '/' in row[1]:
            print ('Bad symbol in ', row[1])
            bad_symbols.append(i)
        else:

            symbol = row[1]
    #         symbol = yf.Ticker(symbol)           

            info = getInfo(symbol)

            if info == 'error':
                symbols_with_no_return.append(row[1])
                print('No return: ', row[1])

            else:

                recent_split = False
                for feature in features:

                    #try twice in case there's a fail that shouldn't happen

                    try:
                        value = info[feature]
                        
                        if feature = 'lastSplitDate':
                            if datetime.datetime.utcfromtimestamp(value) > pd.to_datetime('today') - pd.to_timedelta(days_to_add, unit='d'):
                                stocks.at[i, feature] = datetime.datetime.utcfromtimestamp(value)
                                recent_split = True
                            else:
                                stocks.at[i, feature] = np.nan
                        elif feature = 'lastSplitFactor":
                            if recent_split:
                                stocks.at[i, feature] = value
                            else:
                                stocks.at[i, feature] = np.nan
                        else:
                            stocks.at[i, feature] = value

                    except:
                        stocks.at[i, feature] = np.nan
                        e = sys.exc_info()[0]
                        print(e, ": ", feature) 
        i += 1
    print ('Finished info thread in ', (round(time.time())-initial_time)/ 60.0, " minutes!")
    return stocks[features]

# %%
stocks = QuarterlyInfo(stocks.copy())
# Out:
# <class 'ValueError'>
# <class 'ValueError'>
# <class 'ValueError'>
# Finished quarterly thread in  4.1  minutes!

# %%
stocks
# Out:
#      Symbol                                 Name Exchange            Sector  \
# 0       DDD               3D Systems Corporation     NYSE        Technology
# 1       MMM                           3M Company     NYSE       Health Care
# 2      WUBA                          58.com Inc.     NYSE        Technology
# 3      EGHT                              8x8 Inc     NYSE        Technology
# 4      EGHT                              8x8 Inc   Nasdaq        Technology
# ...     ...                                  ...      ...               ...
# 1755   UFAB             Unique Fabricating, Inc.     AMEX     Capital Goods
# 1756    UEC                 Uranium Energy Corp.     AMEX  Basic Industries
# 1757   VOLT      Volt Information Sciences, Inc.     AMEX        Technology
# 1758    WRN  Western Copper and Gold Corporation     AMEX  Basic Industries
# 1759   ZDGE                          Zedge, Inc.     AMEX        Technology
#
#                                              industry dividendRate  \
# 0             Computer Software: Prepackaged Software          NaN
# 1                          Medical/Dental Instruments          NaN
# 2     Computer Software: Programming, Data Processing          NaN
# 3                                        EDP Services          NaN
# 4                                        EDP Services          NaN
# ...                                               ...          ...
# 1755                                Auto Parts:O.E.M.          NaN
# 1756                                  Precious Metals          NaN
# 1757                            Professional Services          NaN
# 1758                                  Precious Metals          NaN
# 1759          Computer Software: Prepackaged Software          NaN
#
#      exDividendDate lastSplitDate lastSplitFactor Previous_Earnings_Date  \
# 0               NaN           NaN             NaN             2020-08-04
# 1               NaN           NaN             NaN             2020-07-27
# 2               NaN           NaN             NaN             2020-09-03
# 3               NaN           NaN             NaN             2020-07-29
# 4               NaN           NaN             NaN             2020-07-29
# ...             ...           ...             ...                    ...
# 1755            NaN           NaN             NaN             2020-06-24
# 1756            NaN           NaN             NaN             2020-06-08
# 1757            NaN           NaN             NaN             2020-06-15
# 1758            NaN           NaN             NaN             2020-07-27
# 1759            NaN           NaN             NaN             2020-06-10
#
#      Expected Actual Surprise Future Earnings Date
# 0        -0.1  -0.13      -30           2020-10-28
# 1         1.8   1.78    -1.17           2020-10-27
# 2        0.64      -        -           2020-11-16
# 3       -0.12  -0.07   +43.55           2020-10-28
# 4       -0.12  -0.07   +43.55           2020-10-28
# ...       ...    ...      ...                  ...
# 1755     0.03  -0.12     -500                  NaT
# 1756        -      -        -                  NaT
# 1757    -0.41  -0.25   +39.02           2020-09-10
# 1758    -0.01  -0.01        -                  NaT
# 1759        -      -        -           2020-12-08
#
# [1760 rows x 14 columns]

# %%
my_queue = queue.Queue()

t1 = threading.Thread(target=info_thread, args=(stocks.copy(), features,))
t1.start()

# t2 = threading.Thread(target=QuarterlyInfo, args=(stocks.copy(),))
# t2.start()

t1.join()
# t2.join()
# Out:
# Info Thread:  0
# It has been:  0.0  minutes in info thread
# Info Thread:  1
# Info Thread:  2
# Info Thread:  3
# Info Thread:  4
# Info Thread:  5
# Info Thread:  6
# Info Thread:  7
# Info Thread:  8
# Info Thread:  9
# Info Thread:  10
# Info Thread:  11
# Info Thread:  12
# Info Thread:  13
# Info Thread:  14
# Info Thread:  15
# Info Thread:  16
# Info Thread:  17
# Info Thread:  18
# Info Thread:  19
# Info Thread:  20
# Info Thread:  21
# Info Thread:  22
# Info Thread:  23
# Info Thread:  24
# Info Thread:  25
# Info Thread:  26
# Info Thread:  27
# Info Thread:  28
# Info Thread:  29
# Info Thread:  30
# Info Thread:  31
# Info Thread:  32
# Info Thread:  33
# Info Thread:  34
# Info Thread:  35
# Info Thread:  36
# Info Thread:  37
# Info Thread:  38
# Info Thread:  39
# Info Thread:  40
# Info Thread:  41
# Info Thread:  42
# Info Thread:  43
# Info Thread:  44
# Info Thread:  45
# Info Thread:  46
# Info Thread:  47
# Info Thread:  48
# Info Thread:  49
# Info Thread:  50
# Info Thread:  51
# Info Thread:  52
# Info Thread:  53
# Info Thread:  54
# Info Thread:  55
# Info Thread:  56
# Info Thread:  57
# Info Thread:  58
# Info Thread:  59
# Info Thread:  60
# Info Thread:  61
# Info Thread:  62
# Info Thread:  63
# Info Thread:  64
# Info Thread:  65
# Info Thread:  66
# Info Thread:  67
# Info Thread:  68
# Info Thread:  69
# Info Thread:  70
# Info Thread:  71
# Info Thread:  72
# Info Thread:  73
# Info Thread:  74
# Info Thread:  75
# Info Thread:  76
# Info Thread:  77
# Info Thread:  78
# Info Thread:  79
# Info Thread:  80
# Info Thread:  81
# Info Thread:  82
# Info Thread:  83
# Info Thread:  84
# Info Thread:  85
# Info Thread:  86
# Info Thread:  87
# Info Thread:  88
# Info Thread:  89
# Info Thread:  90
# Info Thread:  91
# Info Thread:  92
# Info Thread:  93
# Info Thread:  94
# Info Thread:  95
# Info Thread:  96
# Info Thread:  97
# Info Thread:  98
# Info Thread:  99
# Info Thread:  100
# It has been:  5.166666666666667  minutes in info thread
# Info Thread:  101
# Info Thread:  102
# Info Thread:  103
# Info Thread:  104
# Info Thread:  105
# Info Thread:  106
# Info Thread:  107
# Info Thread:  108
# Info Thread:  109
# Info Thread:  110
# Info Thread:  111
# Info Thread:  112
# Info Thread:  113
# Info Thread:  114
# Info Thread:  115
# Info Thread:  116
# Info Thread:  117
# Info Thread:  118
# Info Thread:  119
# Info Thread:  120
# Info Thread:  121
# Info Thread:  122
# Info Thread:  123
# Info Thread:  124
# Info Thread:  125
# Info Thread:  126
# Info Thread:  127
# Info Thread:  128
# Info Thread:  129
# Info Thread:  130
# Info Thread:  131
# Info Thread:  132
# Info Thread:  133
# Info Thread:  134
# Info Thread:  135
# Info Thread:  136
# Info Thread:  137
# Info Thread:  138
# Info Thread:  139
# Info Thread:  140
# Info Thread:  141
# Info Thread:  142
# Info Thread:  143
# Info Thread:  144
# Info Thread:  145
# Info Thread:  146
# Info Thread:  147
# Info Thread:  148
# Info Thread:  149
# Info Thread:  150
# Info Thread:  151
# Info Thread:  152
# Info Thread:  153
# Info Thread:  154
# Info Thread:  155
# Info Thread:  156
# Info Thread:  157
# Info Thread:  158
# Info Thread:  159
# Info Thread:  160
# Info Thread:  161
# Info Thread:  162
# Info Thread:  163
# Info Thread:  164
# Info Thread:  165
# Info Thread:  166
# Info Thread:  167
# Info Thread:  168
# Info Thread:  169
# Info Thread:  170
# Info Thread:  171
# Info Thread:  172
# Info Thread:  173
# Info Thread:  174
# Info Thread:  175
# Info Thread:  176
# Info Thread:  177
# Info Thread:  178
# Info Thread:  179
# Info Thread:  180
# Info Thread:  181
# Info Thread:  182
# Info Thread:  183
# Info Thread:  184
# Info Thread:  185
# Info Thread:  186
# Info Thread:  187
# Info Thread:  188
# Info Thread:  189
# Info Thread:  190
# Info Thread:  191
# Info Thread:  192
# Info Thread:  193
# Info Thread:  194
# Info Thread:  195
# Info Thread:  196
# Info Thread:  197
# Info Thread:  198
# Info Thread:  199
# Info Thread:  200
# It has been:  10.4  minutes in info thread
# Info Thread:  201
# Info Thread:  202
# Info Thread:  203
# Info Thread:  204
# Info Thread:  205
# Info Thread:  206
# Info Thread:  207
# Info Thread:  208
# Info Thread:  209
# Info Thread:  210
# Info Thread:  211
# Info Thread:  212
# Info Thread:  213
# Info Thread:  214
# Info Thread:  215
# Info Thread:  216
# Info Thread:  217
# Info Thread:  218
# Info Thread:  219
# Info Thread:  220
# Info Thread:  221
# Info Thread:  222
# Info Thread:  223
# Info Thread:  224
# Info Thread:  225
# Info Thread:  226
# Info Thread:  227
# Info Thread:  228
# Info Thread:  229
# Info Thread:  230
# Info Thread:  231
# Info Thread:  232
# Info Thread:  233
# Info Thread:  234
# Info Thread:  235
# Info Thread:  236
# Info Thread:  237
# Info Thread:  238
# Info Thread:  239
# Info Thread:  240
# Info Thread:  241
# Info Thread:  242
# Info Thread:  243
# Info Thread:  244
# Info Thread:  245
# Info Thread:  246
# Info Thread:  247
# Info Thread:  248
# Info Thread:  249
# Info Thread:  250
# Info Thread:  251
# Info Thread:  252
# Info Thread:  253
# Info Thread:  254
# Info Thread:  255
# Info Thread:  256
# Info Thread:  257
# Info Thread:  258
# Info Thread:  259
# Info Thread:  260
# Info Thread:  261
# Info Thread:  262
# Info Thread:  263
# Info Thread:  264
# Info Thread:  265
# Info Thread:  266
# Info Thread:  267
# Info Thread:  268
# Info Thread:  269
# Info Thread:  270
# Info Thread:  271
# Info Thread:  272
# Info Thread:  273
# Info Thread:  274
# Info Thread:  275
# Info Thread:  276
# Info Thread:  277
# Info Thread:  278
# Info Thread:  279
# Info Thread:  280
# Info Thread:  281
# Info Thread:  282
# Info Thread:  283
# Info Thread:  284
# Info Thread:  285
# Info Thread:  286
# Info Thread:  287
# Info Thread:  288
# Info Thread:  289
# Info Thread:  290
# Info Thread:  291
# Info Thread:  292
# Info Thread:  293
# Info Thread:  294
# Info Thread:  295
# Info Thread:  296
# Info Thread:  297
# Info Thread:  298
# Info Thread:  299
# Info Thread:  300
# It has been:  15.733333333333333  minutes in info thread
# Info Thread:  301
# Info Thread:  302
# Info Thread:  303
# Info Thread:  304
# Info Thread:  305
# Info Thread:  306
# Info Thread:  307
# Info Thread:  308
# Info Thread:  309
# Info Thread:  310
# Info Thread:  311
# Info Thread:  312
# Info Thread:  313
# No return:  DSL
# Info Thread:  314
# Info Thread:  315
# Info Thread:  316
# Info Thread:  317
# Info Thread:  318
# Info Thread:  319
# Info Thread:  320
# Info Thread:  321
# Info Thread:  322
# Info Thread:  323
# Info Thread:  324
# Info Thread:  325
# Info Thread:  326
# Info Thread:  327
# Info Thread:  328
# Info Thread:  329
# Info Thread:  330
# Info Thread:  331
# Info Thread:  332
# Info Thread:  333
# Info Thread:  334
# Info Thread:  335
# Info Thread:  336
# Info Thread:  337
# <class 'KeyError'> :  lastSplitDate
# <class 'KeyError'> :  lastSplitFactor
# Info Thread:  338
# Info Thread:  339
# Info Thread:  340
# Info Thread:  341
# Info Thread:  342
# Info Thread:  343
# No return:  FPF
# Info Thread:  344
# Info Thread:  345
# Info Thread:  346
# Info Thread:  347
# Info Thread:  348
# Info Thread:  349
# Info Thread:  350
# Info Thread:  351
# Info Thread:  352
# Info Thread:  353
# Info Thread:  354
# Info Thread:  355
# Info Thread:  356
# Info Thread:  357
# Info Thread:  358
# Info Thread:  359
# Info Thread:  360
# Info Thread:  361
# Info Thread:  362
# Info Thread:  363
# Info Thread:  364
# Info Thread:  365
# HTTP Error 503: Service Unavailable HTTP Error. Will try again in 10 seconds
# Info Thread:  366
# Info Thread:  367
# Info Thread:  368
# Info Thread:  369
# Info Thread:  370
# Info Thread:  371
# Info Thread:  372
# Info Thread:  373
# Info Thread:  374
# Info Thread:  375
# Info Thread:  376
# Info Thread:  377
# Info Thread:  378
# Info Thread:  379
# Info Thread:  380
# Info Thread:  381
# Info Thread:  382
# Info Thread:  383
# Info Thread:  384
# Info Thread:  385
# Info Thread:  386
# Info Thread:  387
# Info Thread:  388
# Info Thread:  389
# Info Thread:  390
# Info Thread:  391
# Info Thread:  392
# Info Thread:  393
# Info Thread:  394
# Info Thread:  395
# Info Thread:  396
# Info Thread:  397
# Info Thread:  398
# Info Thread:  399
# Info Thread:  400
# It has been:  22.166666666666668  minutes in info thread
# Info Thread:  401
# Info Thread:  402
# Info Thread:  403
# Info Thread:  404
# Info Thread:  405
# Info Thread:  406
# Info Thread:  407
# Info Thread:  408
# Info Thread:  409
# Info Thread:  410
# Info Thread:  411
# Info Thread:  412
# Info Thread:  413
# Info Thread:  414
# Info Thread:  415
# Info Thread:  416
# Info Thread:  417
# Info Thread:  418
# Info Thread:  419
# Info Thread:  420
# Info Thread:  421
# Info Thread:  422
# Info Thread:  423
# Info Thread:  424
# Info Thread:  425
# Info Thread:  426
# Info Thread:  427
# Info Thread:  428
# Info Thread:  429
# Info Thread:  430
# Info Thread:  431
# Info Thread:  432
# Info Thread:  433
# Info Thread:  434
# Info Thread:  435
# Info Thread:  436
# Info Thread:  437
# Info Thread:  438
# Info Thread:  439
# Info Thread:  440
# Info Thread:  441
# Info Thread:  442
# Info Thread:  443
# Info Thread:  444
# Info Thread:  445
# Info Thread:  446
# Info Thread:  447
# Info Thread:  448
# Info Thread:  449
# Info Thread:  450
# Info Thread:  451
# Info Thread:  452
# Info Thread:  453
# Info Thread:  454
# Info Thread:  455
# Info Thread:  456
# Info Thread:  457
# Info Thread:  458
# Info Thread:  459
# Info Thread:  460
# Info Thread:  461
# Info Thread:  462
# Info Thread:  463
# Info Thread:  464
# Info Thread:  465
# Info Thread:  466
# Info Thread:  467
# Info Thread:  468
# Info Thread:  469
# Info Thread:  470
# Info Thread:  471
# Info Thread:  472
# Info Thread:  473
# Info Thread:  474
# Info Thread:  475
# Info Thread:  476
# Info Thread:  477
# Info Thread:  478
# Info Thread:  479
# Info Thread:  480
# Info Thread:  481
# Info Thread:  482
# Info Thread:  483
# Info Thread:  484
# Info Thread:  485
# Info Thread:  486
# Info Thread:  487
# Info Thread:  488
# Info Thread:  489
# Info Thread:  490
# Info Thread:  491
# Info Thread:  492
# Info Thread:  493
# Info Thread:  494
# Info Thread:  495
# Info Thread:  496
# Info Thread:  497
# Info Thread:  498
# Info Thread:  499
# Info Thread:  500
# It has been:  27.783333333333335  minutes in info thread
# Info Thread:  501
# Info Thread:  502
# Info Thread:  503
# Info Thread:  504
# Info Thread:  505
# Info Thread:  506
# Info Thread:  507
# No return:  OXM
# Info Thread:  508
# Info Thread:  509
# Info Thread:  510
# Info Thread:  511
# Info Thread:  512
# Info Thread:  513
# Info Thread:  514
# Info Thread:  515
# No return:  PEB
# Info Thread:  516
# Info Thread:  517
# Info Thread:  518
# Info Thread:  519
# Info Thread:  520
# Info Thread:  521
# Info Thread:  522
# Info Thread:  523
# No return:  PIPR
# Info Thread:  524
# Info Thread:  525
# Info Thread:  526
# Info Thread:  527
# No return:  PPG
# Info Thread:  528
# Info Thread:  529
# Info Thread:  530
# Info Thread:  531
# Info Thread:  532
# Info Thread:  533
# Info Thread:  534
# Info Thread:  535
# Info Thread:  536
# Info Thread:  537
# Info Thread:  538
# Info Thread:  539

# %%
my_list = []
while not my_queue.empty():
    my_list.append(my_queue.get())

# %%
stocks = stocks.copy()

for item in my_list:
    print(type(item))
    if 'previous_earnings_date' in item.columns:
        stocks[['previous_earnings_date', 'upcoming_earnings_date']] = item[['previous_earnings_date', 'upcoming_earnings_date']].copy()
    else:
        stocks[features] = item[features].copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
stocks.head(20)
# Out:
#   Symbol                    Name Exchange             Sector  \
# 0    DDD  3D Systems Corporation     NYSE         Technology
# 1    MMM              3M Company     NYSE        Health Care
# 2   WBAI         500.com Limited     NYSE  Consumer Services
# 3   WUBA             58.com Inc.     NYSE         Technology
# 4   EGHT                 8x8 Inc     NYSE         Technology
# 5    AHC   A.H. Belo Corporation     NYSE  Consumer Services
# 6    AOS   A.O Smith Corporation     NYSE  Consumer Durables
# 7   ATEN      A10 Networks, Inc.     NYSE         Technology
# 8    AIR               AAR Corp.     NYSE      Capital Goods
# 9    AAN      Aaron&#39;s,  Inc.     NYSE         Technology
#
#                                           industry dividendRate  \
# 0          Computer Software: Prepackaged Software         None
# 1                       Medical/Dental Instruments         5.88
# 2            Services-Misc. Amusement & Recreation         None
# 3  Computer Software: Programming, Data Processing         None
# 4                                     EDP Services         None
# 5                             Newspapers/Magazines         0.16
# 6                  Consumer Electronics/Appliances         0.96
# 7                Computer Communications Equipment         None
# 8                                        Aerospace          0.3
# 9                  Diversified Commercial Services         0.16
#
#   exDividendDate lastSplitDate lastSplitFactor previous_earnings_date  \
# 0           None    1361750400             3:2    2020-08-05 12:00:00
# 1     1597968000    1064880000             2:1    2020-07-28 12:00:00
# 2           None          None            None    2020-06-26 12:00:00
# 3           None          None            None    2020-07-30 12:00:00
# 4           None          None            None    2013-02-12 12:00:00
# 5     1597276800    1422921600            10:1    2020-07-30 12:00:00
# 6     1596067200    1475712000             2:1    2020-07-28 12:00:00
# 7           None          None            None    2020-07-21 12:00:00
# 8     1585267200     888278400             3:2    2020-07-29 12:00:00
# 9     1600214400    1271376000             3:2                    NaT
#
#   upcoming_earnings_date
# 0    2020-10-28 06:00:00
# 1    2020-10-27 08:00:00
# 2    2020-09-03 04:00:00
# 3    2020-10-28 04:00:00
# 4    2014-10-28 12:00:00
# 5    2020-10-27 08:00:00
# 6    2020-10-27 06:00:00
# 7    2020-09-23 06:00:00
# 8    2020-11-02 06:00:00
# 9                    NaT

# %%
stocks.to_csv('info.csv')

# %%
with open('bad_symbols.txt', 'w') as f:
    for s in bad_symbols:
        f.write(str(s) + "\n")
        
with open('symbols_no_return.txt', 'w') as f:
    for line in symbols_with_no_return:
        f.write(str(line) + "\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-65ad8ddb6711> in <module>
#       1 with open('bad_symbols.txt', 'w') as f:
# ----> 2     for s in bad_symbols:
#       3         f.write(str(s) + "\n")
#       4
#       5 with open('symbols_no_return.txt', 'w') as f:
#
# NameError: name 'bad_symbols' is not defined
